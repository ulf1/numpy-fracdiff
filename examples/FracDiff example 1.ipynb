# %% [markdown]
# # Load Packages

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

import numpy as np
from fracdiff import FracDiff

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
with np.load('data/demo1.npz') as data:
    X = data['px']

# %% [markdown]
# # Transform with FracDiff

# %%
obj = FracDiff(order=0.7)
obj.fit(X)
Z = obj.transform(X)

# %%
for j in range(X.shape[1]):
    plt.plot(Z[:, j]);
    plt.show();
